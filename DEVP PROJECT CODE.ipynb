# %% [markdown]
# PYTHON PROJECT VASU BANSAL 045055
#
# Here, I will be analyzing the famously known Breast Cancer Wisconsin Dataset.
#
# This is an independent project and does not follow any other project done previously using this dataset.
#
# The dataset used is from UC Irvine Lachine Learning Repository.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df=pd.read_csv('data.csv')
print(df)
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %%
#dropping id and unnamed:32 column as they are useless

if 'id' in df.columns:
    df.drop('id', axis=1, inplace=True)

if 'Unnamed: 32' in df.columns:
    df.drop('Unnamed: 32', axis=1, inplace=True)
df.head()
# Out:
#   diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0         M        17.99         10.38          122.80     1001.0
# 1         M        20.57         17.77          132.90     1326.0
# 2         M        19.69         21.25          130.00     1203.0
# 3         M        11.42         20.38           77.58      386.1
# 4         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %%
import seaborn as sns
df['diagnosis'].value_counts()
# Out:
# B    357
# M    212
# Name: diagnosis, dtype: int64

# %%
# Plot a countplot of the 'diagnosis' column
sns.countplot(data=df, x='diagnosis', palette='husl')

# Add labels and a title to the plot
plt.xlabel('Diagnosis')
plt.ylabel('Count')
plt.title('Distribution of Diagnosis')

# Show the plot
plt.show()

# %%
#dataset description
df.describe().T
# Out:
#                          count        mean         std         min  \
# radius_mean              569.0   14.127292    3.524049    6.981000
# texture_mean             569.0   19.289649    4.301036    9.710000
# perimeter_mean           569.0   91.969033   24.298981   43.790000
# area_mean                569.0  654.889104  351.914129  143.500000
# smoothness_mean          569.0    0.096360    0.014064    0.052630
# compactness_mean         569.0    0.104341    0.052813    0.019380
# concavity_mean           569.0    0.088799    0.079720    0.000000
# concave points_mean      569.0    0.048919    0.038803    0.000000
# symmetry_mean            569.0    0.181162    0.027414    0.106000
# fractal_dimension_mean   569.0    0.062798    0.007060    0.049960
# radius_se                569.0    0.405172    0.277313    0.111500
# texture_se               569.0    1.216853    0.551648    0.360200
# perimeter_se             569.0    2.866059    2.021855    0.757000
# ...

# %%
#checking for correlation between various parameters
df.corr()
# Out:
# <ipython-input-8-714bb3557458>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                          radius_mean  texture_mean  perimeter_mean  area_mean  \
# radius_mean                 1.000000      0.323782        0.997855   0.987357
# texture_mean                0.323782      1.000000        0.329533   0.321086
# perimeter_mean              0.997855      0.329533        1.000000   0.986507
# area_mean                   0.987357      0.321086        0.986507   1.000000
# smoothness_mean             0.170581     -0.023389        0.207278   0.177028
# compactness_mean            0.506124      0.236702        0.556936   0.498502
# concavity_mean              0.676764      0.302418        0.716136   0.685983
# concave points_mean         0.822529      0.293464        0.850977   0.823269
# ...

# %%
# Pairplot to visualize relationships between features by diagnosis
sns.pairplot(df, hue="diagnosis", vars=["radius_mean", "texture_mean", "area_mean"])
plt.title("Pairplot of Features by Diagnosis")

# Box plots to visualize feature distributions by diagnosis
plt.figure(figsize=(50, 45))
for i, feature in enumerate(column_names[2:12], 1):
    plt.subplot(3, 4, i)
    sns.boxplot(x="diagnosis", y=feature, data=df)
    plt.title(f"Box Plot of {feature} by Diagnosis")

    # Calculate and annotate min, max, and average for M and B tumors
    min_M = df[df['diagnosis'] == 'M'][feature].min()
    max_M = df[df['diagnosis'] == 'M'][feature].max()
    avg_M = df[df['diagnosis'] == 'M'][feature].mean()

    min_B = df[df['diagnosis'] == 'B'][feature].min()
    max_B = df[df['diagnosis'] == 'B'][feature].max()
    avg_B = df[df['diagnosis'] == 'B'][feature].mean()

    plt.text(0.95, 0.85, f"Min M: {min_M:.2f}\nMax M: {max_M:.2f}\nAvg M: {avg_M:.2f}", transform=plt.gca().transAxes, fontsize=10, verticalalignment='top', horizontalalignment='right')
    plt.text(0.95, 0.15, f"Min B: {min_B:.2f}\nMax B: {max_B:.2f}\nAvg B: {avg_B:.2f}", transform=plt.gca().transAxes, fontsize=10, verticalalignment='bottom', horizontalalignment='right')

# Correlation heatmap
correlation_matrix = df.corr()
plt.figure(figsize=(30, 25))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm")
plt.title("Correlation Heatmap")

plt.show()
# Out:
# <ipython-input-25-6185ead6f2d3>:25: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = df.corr()

# %%
df['diagnosis'] = df['diagnosis'].map({'M':1,'B':0})
# Assuming 'diagnosis' is the target column and other columns are features
target_column = 'radius_mean'

# Calculate the correlation matrix
correlation_matrix = df.corr()

# Sort the correlation values with respect to 'diagnosis' in descending order
correlation_with_target = correlation_matrix[target_column].sort_values(ascending=False)

# Print the sorted correlation values along with the corresponding feature names
print("Correlation with Radius_Mean (in descending order):")
print(correlation_with_target)
# Out:
# Correlation with Radius_Mean (in descending order):
# radius_mean                1.000000
# perimeter_mean             0.997855
# area_mean                  0.987357
# radius_worst               0.969539
# perimeter_worst            0.965137
# area_worst                 0.941082
# concave points_mean        0.822529
# concave points_worst       0.744214
# area_se                    0.735864
# radius_se                  0.679090
# concavity_mean             0.676764
# perimeter_se               0.674172
# concavity_worst            0.526911
# compactness_mean           0.506124
# compactness_worst          0.413463
# concave points_se          0.376169
# texture_mean               0.323782
# texture_worst              0.297008
# compactness_se             0.206000
# concavity_se               0.194204
# smoothness_mean            0.170581
# symmetry_worst             0.163953
# symmetry_mean              0.147741
# smoothness_worst           0.119616
# ...

# %%
#Descriptive Statistics
import pandas as pd


# Select only the numeric columns for analysis
numeric_columns = df.select_dtypes(include=['number'])

# Calculate basic descriptive statistics
statistics = numeric_columns.describe()

# You can also calculate additional statistics individually, such as median, variance, and more
median = numeric_columns.median()
variance = numeric_columns.var()

# Print the descriptive statistics
print(statistics)
print("\nMedian:")
print(median)
print("\nVariance:")
print(variance)
# Out:
#        radius_mean  texture_mean  perimeter_mean    area_mean  \
# count   569.000000    569.000000      569.000000   569.000000
# mean     14.127292     19.289649       91.969033   654.889104
# std       3.524049      4.301036       24.298981   351.914129
# min       6.981000      9.710000       43.790000   143.500000
# 25%      11.700000     16.170000       75.170000   420.300000
# 50%      13.370000     18.840000       86.240000   551.100000
# 75%      15.780000     21.800000      104.100000   782.700000
# max      28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# std           0.014064          0.052813        0.079720             0.038803
# min           0.052630          0.019380        0.000000             0.000000
# ...

# %%
#Comparative Analysis
import pandas as pd

# Assuming you have already loaded your dataset into a DataFrame called 'df'

# Group the data by the 'diagnosis' column (Malignant or Benign)
diagnosis_groups = df.groupby('diagnosis')

# Calculate the mean of numeric columns for each group
means_by_diagnosis = diagnosis_groups.mean()

# You can also calculate other statistics or perform additional analyses here

# Print the means for each group
print("Means by Diagnosis:")
print(means_by_diagnosis)
# Out:
# Means by Diagnosis:
#            radius_mean  texture_mean  perimeter_mean   area_mean  \
# diagnosis
# B            12.146524     17.914762       78.075406  462.790196
# M            17.462830     21.604906      115.365377  978.376415
#
#            smoothness_mean  compactness_mean  concavity_mean  \
# diagnosis
# B                 0.092478          0.080085        0.046058
# M                 0.102898          0.145188        0.160775
#
#            concave points_mean  symmetry_mean  fractal_dimension_mean  ...  \
# diagnosis                                                              ...
# B                     0.025717       0.174186                0.062867  ...
# M                     0.087990       0.192909                0.062680  ...
#
#            radius_worst  texture_worst  perimeter_worst   area_worst  \
# diagnosis
# B             13.379801      23.515070        87.005938   558.899440
# M             21.134811      29.318208       141.370330  1422.286321
#
# ...

# %%
import pandas as pd


# Defining the factors (features) and their corresponding weights

factors = {
    'radius_mean': 0.2,
    'texture_mean': 0.1,
    'smoothness_mean': 0.05,

}

# Calculating the risk score for each row (patient) in the DataFrame
def calculate_risk(row):
    risk = 0
    for feature, weight in factors.items():
        risk += row[feature] * weight
    return risk

# Applying the calculate_risk function to each row
df['risk_score'] = df.apply(calculate_risk, axis=1)


df_sorted = df.sort_values(by='risk_score', ascending=False)

# Printing the DataFrame with risk scores
print(df_sorted[['diagnosis', 'risk_score']])
# Out:
#     diagnosis  risk_score
# 461         M    8.116420
# 180         M    7.636470
# 82          M    7.540315
# 212         M    7.474710
# 239         M    7.424906
# ..        ...         ...
# 504         B    3.148770
# 166         B    3.135797
# 525         B    3.029380
# 59          B    2.907476
# 101         B    2.745050
#
# [569 rows x 2 columns]
